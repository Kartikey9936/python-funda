# %%
def gen_demo():
    yield "hello1"
    yield "hello2"
    yield "hello3"

g = gen_demo()
print(g) #it will give the generator object

# print(next(g))
# print(next(g))

# %%
for i in g:
    print(i)
# Out:
# hello1
# hello2
# hello3
