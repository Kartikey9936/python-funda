# %%
l = [x for x in range(1,10000)]
for i in l :
   print(l*i)

# %%
import sys 
print(sys.getsizeof(l)) #it will give the size of the list in bytes
# Out:
# 85176

# %%
for j in range(1,10000):
    # print(j)
    pass
print(sys.getsizeof(j))
# Out:
# 28

# %%
# for checking dir()
